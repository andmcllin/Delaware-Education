# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import cross_validate
from sklearn.impute import SimpleImputer

# %% [markdown]
# Let's open our xgboostmath model.

# %%
expected_model_version = '1.0'
model_path = './xgboostmath.pkl'
if os.path.exists(model_path):
    with open(model_path, 'rb') as f:
        modelm = pickle.load(f)
    if modelm.version != expected_model_version:
        print("Expected model version doesn't match version loaded")
    if modelm.sklearn_version != sklearn_version:
        print("Warning: model created under different sklearn version")
else:
    print("Expected model not found")

# %% [markdown]
# I will retrain the model on our entire dataset then use it to predict the performance of the state of Delaware as a whole on math proficiency.

# %%
math_data = pd.read_csv('SBSA_math.csv')
math_data
# Out:
#      PctProficient  ScaleScoreAvg  FallEnrollment  \
# 0            59.75            NaN           699.0
# 1            65.12            NaN           436.0
# 2            57.60            NaN           442.0
# 3            68.15            NaN           495.0
# 4            56.66            NaN           542.0
# ..             ...            ...             ...
# 813          14.17        2388.06           613.0
# 814          42.86        2493.83           600.0
# 815          42.86        2493.83           600.0
# 816          18.69        2366.36           341.0
# 817          18.69        2366.36           341.0
#
#      Students Per Teacher, Regular  Students Per Teacher, Special  \
# 0                        19.971429                     116.500000
# 1                        16.769231                     145.333333
# 2                        17.680000                      55.250000
# 3                        19.800000                     123.750000
# 4                        19.357143                     180.666667
# ..                             ...                            ...
# 813                      17.514286                     153.250000
# 814                      18.181818                            NaN
# 815                      18.181818                            NaN
# 816                      24.357143                     170.500000
# 817                      24.357143                     170.500000
#
#      Students Per Specialist, Instructional  \
# 0                                    699.00
# 1                                    436.00
# 2                                       NaN
# 3                                    495.00
# 4                                       NaN
# ..                                      ...
# 813                                     NaN
# 814                                     NaN
# 815                                     NaN
# 816                                   85.25
# 817                                   85.25
#
#      Students Per Assistant Superintendent  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 813                                    NaN
# 814                                    NaN
# 815                                    NaN
# 816                                    NaN
# 817                                    NaN
#
#      Students Per Administrative Assistant  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 813                                  613.0
# 814                                  150.0
# 815                                  150.0
# 816                                    NaN
# 817                                    NaN
#
#      Students Per Supervisor, Pupil Support  Students Per Crafts & Trades  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# ..                                      ...                           ...
# 813                                     NaN                           NaN
# 814                                     NaN                         600.0
# 815                                     NaN                         600.0
# 816                                     NaN                           NaN
# 817                                     NaN                           NaN
#
#      ...  Students Per Nurse  Students Per Social Worker  \
# 0    ...               699.0                         NaN
# 1    ...                 NaN                         NaN
# 2    ...               442.0                         NaN
# 3    ...               495.0                         NaN
# 4    ...               542.0                         NaN
# ..   ...                 ...                         ...
# 813  ...               613.0                         NaN
# 814  ...               300.0                         NaN
# 815  ...               300.0                         NaN
# 816  ...               341.0                       170.5
# 817  ...               341.0                       170.5
#
#      Students Per Principal  Students Per Guidance Counselor  \
# 0                     699.0                            699.0
# 1                     436.0                            436.0
# 2                     442.0                            442.0
# 3                     495.0                            495.0
# 4                     542.0                            542.0
# ..                      ...                              ...
# 813                     NaN                              NaN
# 814                   600.0                              NaN
# 815                   600.0                              NaN
# 816                     NaN                              NaN
# 817                     NaN                              NaN
#
#      Students Per Assistant Principal  Students Per Librarian  \
# 0                                 NaN                     NaN
# 1                               436.0                   436.0
# 2                               442.0                   442.0
# 3                               495.0                   495.0
# 4                                 NaN                   542.0
# ..                                ...                     ...
# 813                               NaN                     NaN
# 814                               NaN                   600.0
# 815                               NaN                   600.0
# 816                               NaN                     NaN
# 817                               NaN                     NaN
#
#      Students Per Service Aide  Students Per Bus Driver & Laborer  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                        495.0                                NaN
# 4                          NaN                                NaN
# ..                         ...                                ...
# 813                        NaN                             76.625
# 814                        NaN                                NaN
# 815                        NaN                                NaN
# 816                        NaN                                NaN
# 817                        NaN                                NaN
#
#      Students Per Other General Support  Students Per Psychometrist
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ..                                  ...                         ...
# 813                          204.333333                         NaN
# 814                                 NaN                         NaN
# 815                                 NaN                         NaN
# 816                          341.000000                         NaN
# 817                          341.000000                         NaN
#
# [818 rows x 37 columns]

# %%
X = math_data[modelm.X_columns]
y = math_data['PctProficient']

# %%
len(X), len(y)
# Out:
# (818, 818)

# %% [markdown]
# Fit the model to the entire dataset.

# %%
modelm.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
cv_results = cross_validate(modelm, X, y, scoring='neg_mean_absolute_error', cv=5, n_jobs=-1)

# %%
cv_results['test_score']
# Out:
# array([-12.19651864, -10.02295218, -12.85816164, -11.17770319,
#         -9.5965747 ])

# %%
mae_mean, mae_std = np.mean(-1 * cv_results['test_score']), np.std(-1 * cv_results['test_score'])
mae_mean, mae_std
# Out:
# (11.170382068203788, 1.2405704118374818)

# %% [markdown]
# Get the mean absolute error and mean standard deviation of our model. Then get the stats for the state of Delaware as a whole.

# %%
Delaware_math = pd.read_csv('StateofDelawarestats.csv')
Delaware_math = Delaware_math[Delaware_math['ContentArea'] == 'MATH']
Delaware_math
# Out:
#    School Year  School Code       Organization  \
# 1         2022            0  State of Delaware
#
#                          Assessment Name ContentArea         Grade  \
# 1  Smarter Balanced Summative Assessment        MATH  All Students
#
#    PctProficient  FallEnrollment  Students Per Teacher, Regular  \
# 1          30.21        140263.0                      18.743719
#
#    Students Per Teacher, Special  ...  Students Per Assistant Superintendent  \
# 1                      53.953533  ...                              8766.4375
#
#    Students Per Speech and Hearing Therapist  \
# 1                                  684.87793
#
#    Students Per Bus Driver & Laborer  Students Per Psychologist  \
# 1                         304.919565                 638.429677
#
#    Students Per Managerial  Students Per Principal  \
# 1               882.157233              623.391111
#
#    Students Per Superintendent  Students Per Teaching & Clerical Aide  \
# 1                  6375.590909                              48.721039
#
#    Students Per Specialist, Instructional  Students Per Psychometrist
# 1                              476.113374                         NaN
#
# [1 rows x 42 columns]

# %%
X_del = Delaware_math.loc[Delaware_math.Organization == "State of Delaware", modelm.X_columns]
y_del = Delaware_math.loc[Delaware_math.Organization == "State of Delaware", 'PctProficient']

# %%
del_pred = modelm.predict(X_del).item()

# %%
y_del = y_del.values.item()

# %%
print(f'The predicted PctProficient for math is {del_pred:.2f}, actual PctProficient is {y_del:.2f}.')
print(f'The expected mean absolute error of {mae_mean:.2f}.')
# Out:
# The predicted PctProficient for math is 42.89, actual PctProficient is 30.21.
# The expected mean absolute error of 11.17.

# %% [markdown]
# The model predicts that math proficiency in the state should be at 42.89%, while in reality the proficiency sits at 30.21%. This is a bigger difference than the mean absolute error. There are a number of reasons why this may be. The first is that proficiency scores are not normally distributed across schools. Another is that COVID learning loss may have affected math proficiency in a dramatic way. Or it could be a fluke down here. Whatever the case this suggests that math scores will improve in the state regardless of action taken to change staffing levels. A somewhat unsatisfying conclusion, but lets try to improve on the model score regardless.

# %%
def predict_increase(features, deltas):
    
    dele2 = X_del.copy()
    for f, d in zip(features, deltas):
        dele2[f] += d
    return modelm.predict(dele2).item() - modelm.predict(X_del).item()

# %% [markdown]
# Students per Assistant Principal, and Students Per Director were the most important features in creating our model. Let's try changing the student staff ratio for both these positions and maximize the model proficiency.

# %%
proficiency_increase = 0
icounter = 0
jcounter = 0

for i in range(-1, -100, -1):
    for j in np.arange(-1, -100, -1):
        proficiency_increase_temp = predict_increase(['Students Per Assistant Principal', 'Students Per Director'], [i, j])
        if proficiency_increase_temp > proficiency_increase:
            proficiency_increase = proficiency_increase_temp
            icounter = i
            jcounter = j


print('A decrease in students per assistant principal by ' + str(icounter) + ' and director by ' + str(jcounter) + ' will improve the model proficiency by ' + \
    str(proficiency_increase) + '%.')
# Out:
# A decrease in students per assistant principal by -17 and director by -1 will improve the model proficiency by 2.4587249755859375%.

# %% [markdown]
# Not a very big increase in performance. Dissapointing; let's try English.

# %%
expected_model_version = '1.0'
model_path = './xgboostela.pkl'
if os.path.exists(model_path):
    with open(model_path, 'rb') as f:
        modele = pickle.load(f)
    if modele.version != expected_model_version:
        print("Expected model version doesn't match version loaded")
    if modele.sklearn_version != sklearn_version:
        print("Warning: model created under different sklearn version")
else:
    print("Expected model not found")

# %% [markdown]
# I will go through the same steps with this model as I did with the math model.

# %%
ela_data = pd.read_csv('SBSA_ela.csv')
ela_data
# Out:
#       PctProficient  ScaleScoreAvg  FallEnrollment  \
# 0             69.06            NaN           699.0
# 1             80.84            NaN           436.0
# 2             63.08            NaN           442.0
# 3             75.00            NaN           495.0
# 4             73.04            NaN           542.0
# ...             ...            ...             ...
# 1141          33.33        2491.88           285.0
# 1142          11.36        2447.20           503.0
# 1143          11.36        2447.20           503.0
# 1144          28.44        2390.86           341.0
# 1145          28.44        2390.86           341.0
#
#       Students Per Teacher, Regular  Students Per Teacher, Special  \
# 0                         19.971429                     116.500000
# 1                         16.769231                     145.333333
# 2                         17.680000                      55.250000
# 3                         19.800000                     123.750000
# 4                         19.357143                     180.666667
# ...                             ...                            ...
# 1141                      15.000000                      71.250000
# 1142                      16.225806                     503.000000
# 1143                      16.225806                     503.000000
# 1144                      24.357143                     170.500000
# 1145                      24.357143                     170.500000
#
#       Students Per Specialist, Instructional  \
# 0                                     699.00
# 1                                     436.00
# 2                                        NaN
# 3                                     495.00
# 4                                        NaN
# ...                                      ...
# 1141                                  142.50
# 1142                                     NaN
# 1143                                     NaN
# 1144                                   85.25
# 1145                                   85.25
#
#       Students Per Assistant Superintendent  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1141                                    NaN
# 1142                                    NaN
# 1143                                    NaN
# 1144                                    NaN
# 1145                                    NaN
#
#       Students Per Administrative Assistant  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1141                                  142.5
# 1142                                    NaN
# 1143                                    NaN
# 1144                                    NaN
# 1145                                    NaN
#
#       Students Per Supervisor, Pupil Support  Students Per Crafts & Trades  \
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 1141                                     NaN                           NaN
# 1142                                     NaN                           NaN
# 1143                                     NaN                           NaN
# 1144                                     NaN                           NaN
# 1145                                     NaN                           NaN
#
#       ...  Students Per Nurse  Students Per Social Worker  \
# 0     ...               699.0                         NaN
# 1     ...                 NaN                         NaN
# 2     ...               442.0                         NaN
# 3     ...               495.0                         NaN
# 4     ...               542.0                         NaN
# ...   ...                 ...                         ...
# 1141  ...               285.0                         NaN
# 1142  ...               503.0                         NaN
# 1143  ...               503.0                         NaN
# 1144  ...               341.0                       170.5
# 1145  ...               341.0                       170.5
#
#       Students Per Principal  Students Per Guidance Counselor  \
# 0                      699.0                            699.0
# 1                      436.0                            436.0
# 2                      442.0                            442.0
# 3                      495.0                            495.0
# 4                      542.0                            542.0
# ...                      ...                              ...
# 1141                    95.0                            285.0
# 1142                   503.0                            251.5
# 1143                   503.0                            251.5
# 1144                     NaN                              NaN
# 1145                     NaN                              NaN
#
#       Students Per Assistant Principal  Students Per Librarian  \
# 0                                  NaN                     NaN
# 1                                436.0                   436.0
# 2                                442.0                   442.0
# 3                                495.0                   495.0
# 4                                  NaN                   542.0
# ...                                ...                     ...
# 1141                              95.0                     NaN
# 1142                               NaN                     NaN
# 1143                               NaN                     NaN
# 1144                               NaN                     NaN
# 1145                               NaN                     NaN
#
#       Students Per Service Aide  Students Per Bus Driver & Laborer  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                         495.0                                NaN
# 4                           NaN                                NaN
# ...                         ...                                ...
# 1141                        NaN                                NaN
# 1142                      503.0                                NaN
# 1143                      503.0                                NaN
# 1144                        NaN                                NaN
# 1145                        NaN                                NaN
#
#       Students Per Other General Support  Students Per Psychometrist
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    NaN                         NaN
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
# ...                                  ...                         ...
# 1141                                 NaN                         NaN
# 1142                                 NaN                         NaN
# 1143                                 NaN                         NaN
# 1144                               341.0                         NaN
# 1145                               341.0                         NaN
#
# [1146 rows x 37 columns]

# %%
X = ela_data[modele.X_columns]
y = ela_data['PctProficient']

# %%
len(X), len(y)
# Out:
# (1146, 1146)

# %%
modele.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=700, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
cv_results = cross_validate(modele, X, y, scoring='neg_mean_absolute_error', cv=5, n_jobs=-1)

# %%
cv_results['test_score']
# Out:
# array([ -9.89241583,  -7.387582  ,  -7.87582363,  -8.78458863,
#        -10.91375004])

# %%
mae_mean, mae_std = np.mean(-1 * cv_results['test_score']), np.std(-1 * cv_results['test_score'])
mae_mean, mae_std
# Out:
# (8.97083202513765, 1.2934185509606109)

# %%
Delaware_ela = pd.read_csv('StateofDelawarestats.csv')
Delaware_ela = Delaware_ela[Delaware_ela['ContentArea'] == 'ELA']
Delaware_ela
# Out:
#    School Year  School Code       Organization  \
# 0         2022            0  State of Delaware
#
#                          Assessment Name ContentArea         Grade  \
# 0  Smarter Balanced Summative Assessment         ELA  All Students
#
#    PctProficient  FallEnrollment  Students Per Teacher, Regular  \
# 0          41.69        140263.0                      18.743719
#
#    Students Per Teacher, Special  ...  Students Per Assistant Superintendent  \
# 0                      53.953533  ...                              8766.4375
#
#    Students Per Speech and Hearing Therapist  \
# 0                                  684.87793
#
#    Students Per Bus Driver & Laborer  Students Per Psychologist  \
# 0                         304.919565                 638.429677
#
#    Students Per Managerial  Students Per Principal  \
# 0               882.157233              623.391111
#
#    Students Per Superintendent  Students Per Teaching & Clerical Aide  \
# 0                  6375.590909                              48.721039
#
#    Students Per Specialist, Instructional  Students Per Psychometrist
# 0                              476.113374                         NaN
#
# [1 rows x 42 columns]

# %%
X_del = Delaware_ela.loc[Delaware_ela.Organization == "State of Delaware", modele.X_columns]
y_del = Delaware_ela.loc[Delaware_ela.Organization == "State of Delaware", 'PctProficient']

# %%
del_pred = modele.predict(X_del).item()

# %%
y_del = y_del.values.item()

# %%
print(f'The predicted PctProficient for ela is {del_pred:.2f}, actual PctProficient is {y_del:.2f}.')
print(f'The expected mean absolute error of {mae_mean:.2f}.')
# Out:
# The predicted PctProficient for ela is 39.43, actual PctProficient is 41.69.
# The expected mean absolute error of 8.97.

# %% [markdown]
# This seems to suggest that this models performs a lot better than the math model.

# %%
def predict_increase(features, deltas):
    
    dele2 = X_del.copy()
    for f, d in zip(features, deltas):
        dele2[f] += d
    return modele.predict(dele2).item() - modele.predict(X_del).item()

# %%
proficiency_increase = 0
icounter = 0
jcounter = 0

for i in range(-1, -100, -1):
    for j in np.arange(-1, -100, -1):
        proficiency_increase_temp = predict_increase(['Students Per Assistant Principal', 'Students Per Director'], [i, j])
        if proficiency_increase_temp > proficiency_increase:
            proficiency_increase = proficiency_increase_temp
            icounter = i
            jcounter = j


print('A decrease in students per assistant principal by ' + str(icounter) + ' and director by ' + str(jcounter) + ' will improve the model proficiency by ' + \
    str(proficiency_increase) + '%.')
# Out:
# A decrease in students per assistant principal by -89 and director by -1 will improve the model proficiency by 11.994335174560547%.

# %% [markdown]
# Here it appears that adding more assistant principals will improve the performance of the state on the English Language Arts version of the SBSA. But how many assistant principals is that?

# %%
Delaware_ela['Students Per Assistant Principal'], (Delaware_ela['Students Per Assistant Principal'] - 89)
# Out:
# (0    448.411125
#  Name: Students Per Assistant Principal, dtype: float64,
#  0    359.411125
#  Name: Students Per Assistant Principal, dtype: float64)

# %% [markdown]
# There are currently 448 students per assistant principal we want to get that down to 359.

# %%
delaware_enrollment = pd.read_csv('Student_Enrollment.csv')
delaware_enrollment.head()
# Out:
#    School Year  District Code           District  School Code  \
# 0         2015              0  State of Delaware            0
# 1         2015              0  State of Delaware            0
# 2         2015              0  State of Delaware            0
# 3         2015              0  State of Delaware            0
# 4         2015              0  State of Delaware            0
#
#         Organization   Race        Gender         Grade   SpecialDemo  \
# 0  State of Delaware  White  All Students     9th Grade  All Students
# 1  State of Delaware  White  All Students       Twelfth  All Students
# 2  State of Delaware  White  All Students  All Students  All Students
# 3  State of Delaware  White        Female     4th Grade      Homeless
# 4  State of Delaware  White        Female     4th Grade    Low-Income
#
#       Geography                           SubGroup RowStatus  Students  \
# 0  All Students                    White/9th Grade  REPORTED    5631.0
# 1  All Students                      White/Twelfth  REPORTED    4828.0
# 2  All Students                              White  REPORTED   65185.0
# 3  All Students    White/Female/4th Grade/Homeless  REDACTED      37.0
# 4  All Students  White/Female/4th Grade/Low-Income  REPORTED     600.0
#
#    EOYEnrollment  PctOfEOYEnrollment  FallEnrollment
# 0       141336.0                3.98        134932.0
# 1       141336.0                3.42        134932.0
# 2       141336.0               46.12        134932.0
# 3       141336.0                0.03             NaN
# 4       141336.0                0.42        134932.0

# %%
delaware_enrollment = delaware_enrollment[delaware_enrollment['School Year'] == 2022]
delaware_enrollment['FallEnrollment'].max()
# Out:
# 140263.0

# %% [markdown]
# There were 140263 students enrolled in the 2021-2022 school year.

# %%
140263 / 448.411
# Out:
# 312.80008741980015

# %% [markdown]
# Meaning there were 313 assistant principals in the state.

# %%
140263 / 359.411
# Out:
# 390.25794981233184

# %% [markdown]
# We want to increase that to 390 principals, an increase of 77 staff. How much would that cost?

# %%
delaware_ap_salary = pd.read_csv('Educator_Average_Salary.csv')
delaware_ap_salary.head()
# Out:
#    School Year  District Code                District  School Code  \
# 0         2020             24  Smyrna School District          697
# 1         2020             24  Smyrna School District          697
# 2         2020             24  Smyrna School District          697
# 3         2020             24  Smyrna School District          697
# 4         2020             24  Smyrna School District          697
#
#                    Organization   Race         Gender          Grade  \
# 0  Smyrna Administrative Office  White  All Educators  All Educators
# 1  Smyrna Administrative Office  White  All Educators  All Educators
# 2  Smyrna Administrative Office  White  All Educators  All Educators
# 3  Smyrna Administrative Office  White  All Educators  All Educators
# 4  Smyrna Administrative Office  White  All Educators  All Educators
#
#      SpecialDemo      Geography  ...           Staff Category  \
# 0        Regular  All Educators  ...  Official/Administrative
# 1        Regular  All Educators  ...            Pupil Support
# 2  All Educators  All Educators  ...                      ALL
# 3        Regular  All Educators  ...    Instructional Support
# 4  All Educators  All Educators  ...                      ALL
#
#           Job Classification Experience Educators (FTE) Average Total Salary  \
# 0                        ALL        ALL            14.0             95625.22
# 1                        ALL        ALL             1.0             97917.55
# 2                        ALL        ALL            25.0             48982.63
# 3  Supervisor, Instructional        ALL             3.0            115362.61
# 4                        ALL        ALL            46.0             69886.27
#
#    Average State Salary  Average Local Salary  Average Federal Salary  \
# 0              54023.65              41601.56                     NaN
# 1              60056.88              37860.68                     NaN
# 2              35892.53              13090.10                     NaN
# 3              64883.95              50478.65                     NaN
# 4              44649.62              25236.64                     NaN
#
#    Average Years of Experience  Average Years of Age
# 0                           19                    53
# 1                            1                    33
# 2                           20                    46
# 3                           12                    53
# 4                           19                    48
#
# [5 rows x 22 columns]

# %%
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['Job Classification'] == 'Assistant Principal']
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['Organization'] == 'State of Delaware']
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['SpecialDemo'] == 'All Educators']
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['Race'] == 'All Educators']
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['Gender'] == 'All Educators']
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['Experience'] == 'ALL']
delaware_ap_salary = delaware_ap_salary[delaware_ap_salary['School Year'] == 2022]
delaware_ap_salary
# Out:
#          School Year  District Code           District  School Code  \
# 1633927         2022              0  State of Delaware            0
#
#               Organization           Race         Gender          Grade  \
# 1633927  State of Delaware  All Educators  All Educators  All Educators
#
#            SpecialDemo      Geography  ...           Staff Category  \
# 1633927  All Educators  All Educators  ...  Official/Administrative
#
#           Job Classification Experience Educators (FTE) Average Total Salary  \
# 1633927  Assistant Principal        ALL           312.8            112222.42
#
#          Average State Salary  Average Local Salary  Average Federal Salary  \
# 1633927              65941.47              52236.87                83283.72
#
#          Average Years of Experience  Average Years of Age
# 1633927                           15                    45
#
# [1 rows x 22 columns]

# %% [markdown]
# The average salary of an assistant principal was $112222.42 in 2022 an increase of 77 of them at the average salary would cost:

# %%
112222.42 * 77
# Out:
# 8641126.34

# %% [markdown]
# About 8 and a half million dollars, well within our budget.
